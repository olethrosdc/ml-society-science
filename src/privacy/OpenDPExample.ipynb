# %%
import opendp as odp
odp.mod.enable_features('contrib') # enable unvetted code

# %%
## Perform a trivial transformation
from opendp.trans import make_identity
from opendp.typing import VectorDomain, AllDomain, SymmetricDistance
# D= Input/Output Domain
# M = Metric
identity = make_identity(D=VectorDomain[AllDomain[str]], M=SymmetricDistance)
identity(["hello, world"])
# Out:
# ['hello, world']

# %%
# Out:
# Help on module opendp.trans in opendp:
#
# NAME
#     opendp.trans - # Auto-generated. Do not edit.
#
# FUNCTIONS
#     make_bounded_resize(size:int, bounds:Tuple[Any, Any], constant, TA:Union[_ForwardRef('RuntimeType'), GenericMeta, str, Type[Union[List, Tuple, int, float, str]], tuple]=None) -> opendp.mod.Transformation
#         Make a Transformation that either truncates or imputes records with `constant` in a Vec<`TA`> to match a provided `size`.
#
#         :param size: Number of records in output data.
#         :type size: int
#         :param bounds: Tuple of lower and upper bounds for data in the input domain
#         :type bounds: Tuple[Any, Any]
#         :param constant: Value to impute with.
#         :param TA: Atomic type. If not passed, TA is inferred from the lower bound.
#         :type TA: RuntimeTypeDescriptor
#         :return: A vector of the same type `TA`, but with the provided `size`.
#         :rtype: Transformation
# ...
