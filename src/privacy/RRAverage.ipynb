# %%
from randomised_response import rp_binary

# %%
n_people = 100000
n_features = 1

drug_use = 0.1
import numpy as np
data = np.random.choice(2, size=[n_people, n_features], p = [1 - drug_use, drug_use])

# %%
error = abs(np.mean(data) - drug_use)
print(error)
# Out:
# 6.0000000000004494e-05

# %%
import matplotlib.pyplot as plt
epsilon_range = np.linspace(0,10)

errors_all = [abs(drug_use - np.mean(rp_binary(data, epsilon))) for epsilon in epsilon_range ]
errors_10 = [abs(drug_use - np.mean(rp_binary(data[1:10000], epsilon))) for epsilon in epsilon_range ]
errors_100 = [abs(drug_use - np.mean(rp_binary(data[1:1000], epsilon))) for epsilon in epsilon_range ]
errors_1000 = [abs(drug_use - np.mean(rp_binary(data[1:100], epsilon))) for epsilon in epsilon_range ]
errors_10000 = [abs(drug_use - np.mean(rp_binary(data[1:10], epsilon))) for epsilon in epsilon_range ]
# Out:
# Using a p of  0.5
# Using a p of  0.4491559378157573
# Using a p of  0.3993526173392569
# Using a p of  0.35154727657611745
# Using a p of  0.30654399138843724
# Using a p of  0.2649479029028563
# Using a p of  0.2271472951759427
# Using a p of  0.19332136980230868
# Using a p of  0.16346724250610573
# Using a p of  0.13743793244815447
# Using a p of  0.11498363458710673
# Using a p of  0.09579046596165096
# Using a p of  0.07951320168980049
# Using a p of  0.06580058306394546
# Using a p of  0.05431326613264062
# Using a p of  0.0447353464057362
# Using a p of  0.03678076158088027
# Using a p of  0.03019590537835197
# Using a p of  0.02475963197867261
# Using a p of  0.02028160182709456
# Using a p of  0.01659968341582421
# Using a p of  0.013576916943744364
# Using a p of  0.011098377611465081
# Using a p of  0.009068149441355245
# Using a p of  0.007406529685701493
# Using a p of  0.006047521873600132
# Using a p of  0.004936635218900832
# Using a p of  0.004028983358498858
# Using a p of  0.003287661385934009
# Using a p of  0.0026823732796317037
# Using a p of  0.0021882795075905265
# Using a p of  0.0017850350245561864
# Using a p of  0.0014559898567672236
# Using a p of  0.001187527207869261
# Using a p of  0.000968517024997084
# Using a p of  0.0007898659417364615
# Using a p of  0.0006441473006074265
# Using a p of  0.0005252974713971296
# Using a p of  0.00042836689448632817
# Using a p of  0.00034931619233910023
# Using a p of  0.00028484932661867926
# Using a p of  0.000232277160288464
# Using a p of  0.00018940594382518605
# Using a p of  0.0001544462123729689
# Using a p of  0.0001259383844336104
# Using a p of  0.00010269201788605237
# Using a p of  8.373622806675614e-05
# Using a p of  6.827922460227623e-05
# Using a p of  5.5675295113294124e-05
# Using a p of  4.5397868702434395e-05
# Using a p of  0.5
# Using a p of  0.4491559378157573
# Using a p of  0.3993526173392569
# Using a p of  0.35154727657611745
# Using a p of  0.30654399138843724
# Using a p of  0.2649479029028563
# Using a p of  0.2271472951759427
# Using a p of  0.19332136980230868
# Using a p of  0.16346724250610573
# Using a p of  0.13743793244815447
# Using a p of  0.11498363458710673
# Using a p of  0.09579046596165096
# Using a p of  0.07951320168980049
# Using a p of  0.06580058306394546
# Using a p of  0.05431326613264062
# Using a p of  0.0447353464057362
# Using a p of  0.03678076158088027
# Using a p of  0.03019590537835197
# Using a p of  0.02475963197867261
# Using a p of  0.02028160182709456
# Using a p of  0.01659968341582421
# Using a p of  0.013576916943744364
# Using a p of  0.011098377611465081
# Using a p of  0.009068149441355245
# Using a p of  0.007406529685701493
# Using a p of  0.006047521873600132
# Using a p of  0.004936635218900832
# Using a p of  0.004028983358498858
# Using a p of  0.003287661385934009
# Using a p of  0.0026823732796317037
# Using a p of  0.0021882795075905265
# Using a p of  0.0017850350245561864
# Using a p of  0.0014559898567672236
# Using a p of  0.001187527207869261
# Using a p of  0.000968517024997084
# Using a p of  0.0007898659417364615
# Using a p of  0.0006441473006074265
# Using a p of  0.0005252974713971296
# Using a p of  0.00042836689448632817
# Using a p of  0.00034931619233910023
# Using a p of  0.00028484932661867926
# Using a p of  0.000232277160288464
# Using a p of  0.00018940594382518605
# Using a p of  0.0001544462123729689
# Using a p of  0.0001259383844336104
# Using a p of  0.00010269201788605237
# Using a p of  8.373622806675614e-05
# Using a p of  6.827922460227623e-05
# Using a p of  5.5675295113294124e-05
# Using a p of  4.5397868702434395e-05
# Using a p of  0.5
# Using a p of  0.4491559378157573
# Using a p of  0.3993526173392569
# Using a p of  0.35154727657611745
# Using a p of  0.30654399138843724
# Using a p of  0.2649479029028563
# Using a p of  0.2271472951759427
# Using a p of  0.19332136980230868
# Using a p of  0.16346724250610573
# Using a p of  0.13743793244815447
# Using a p of  0.11498363458710673
# Using a p of  0.09579046596165096
# Using a p of  0.07951320168980049
# Using a p of  0.06580058306394546
# Using a p of  0.05431326613264062
# Using a p of  0.0447353464057362
# Using a p of  0.03678076158088027
# Using a p of  0.03019590537835197
# Using a p of  0.02475963197867261
# Using a p of  0.02028160182709456
# Using a p of  0.01659968341582421
# Using a p of  0.013576916943744364
# Using a p of  0.011098377611465081
# Using a p of  0.009068149441355245
# Using a p of  0.007406529685701493
# Using a p of  0.006047521873600132
# Using a p of  0.004936635218900832
# Using a p of  0.004028983358498858
# Using a p of  0.003287661385934009
# Using a p of  0.0026823732796317037
# Using a p of  0.0021882795075905265
# Using a p of  0.0017850350245561864
# Using a p of  0.0014559898567672236
# Using a p of  0.001187527207869261
# Using a p of  0.000968517024997084
# Using a p of  0.0007898659417364615
# Using a p of  0.0006441473006074265
# Using a p of  0.0005252974713971296
# Using a p of  0.00042836689448632817
# Using a p of  0.00034931619233910023
# Using a p of  0.00028484932661867926
# Using a p of  0.000232277160288464
# Using a p of  0.00018940594382518605
# Using a p of  0.0001544462123729689
# Using a p of  0.0001259383844336104
# Using a p of  0.00010269201788605237
# Using a p of  8.373622806675614e-05
# Using a p of  6.827922460227623e-05
# Using a p of  5.5675295113294124e-05
# Using a p of  4.5397868702434395e-05
# Using a p of  0.5
# Using a p of  0.4491559378157573
# Using a p of  0.3993526173392569
# Using a p of  0.35154727657611745
# Using a p of  0.30654399138843724
# Using a p of  0.2649479029028563
# Using a p of  0.2271472951759427
# Using a p of  0.19332136980230868
# Using a p of  0.16346724250610573
# Using a p of  0.13743793244815447
# Using a p of  0.11498363458710673
# Using a p of  0.09579046596165096
# Using a p of  0.07951320168980049
# Using a p of  0.06580058306394546
# Using a p of  0.05431326613264062
# Using a p of  0.0447353464057362
# Using a p of  0.03678076158088027
# Using a p of  0.03019590537835197
# Using a p of  0.02475963197867261
# Using a p of  0.02028160182709456
# Using a p of  0.01659968341582421
# Using a p of  0.013576916943744364
# Using a p of  0.011098377611465081
# Using a p of  0.009068149441355245
# Using a p of  0.007406529685701493
# Using a p of  0.006047521873600132
# Using a p of  0.004936635218900832
# Using a p of  0.004028983358498858
# Using a p of  0.003287661385934009
# Using a p of  0.0026823732796317037
# Using a p of  0.0021882795075905265
# Using a p of  0.0017850350245561864
# Using a p of  0.0014559898567672236
# Using a p of  0.001187527207869261
# Using a p of  0.000968517024997084
# Using a p of  0.0007898659417364615
# Using a p of  0.0006441473006074265
# Using a p of  0.0005252974713971296
# Using a p of  0.00042836689448632817
# Using a p of  0.00034931619233910023
# Using a p of  0.00028484932661867926
# Using a p of  0.000232277160288464
# Using a p of  0.00018940594382518605
# Using a p of  0.0001544462123729689
# Using a p of  0.0001259383844336104
# Using a p of  0.00010269201788605237
# Using a p of  8.373622806675614e-05
# Using a p of  6.827922460227623e-05
# Using a p of  5.5675295113294124e-05
# Using a p of  4.5397868702434395e-05
# Using a p of  0.5
# Using a p of  0.4491559378157573
# Using a p of  0.3993526173392569
# Using a p of  0.35154727657611745
# Using a p of  0.30654399138843724
# Using a p of  0.2649479029028563
# Using a p of  0.2271472951759427
# Using a p of  0.19332136980230868
# Using a p of  0.16346724250610573
# Using a p of  0.13743793244815447
# Using a p of  0.11498363458710673
# Using a p of  0.09579046596165096
# Using a p of  0.07951320168980049
# Using a p of  0.06580058306394546
# Using a p of  0.05431326613264062
# Using a p of  0.0447353464057362
# Using a p of  0.03678076158088027
# Using a p of  0.03019590537835197
# Using a p of  0.02475963197867261
# Using a p of  0.02028160182709456
# Using a p of  0.01659968341582421
# Using a p of  0.013576916943744364
# Using a p of  0.011098377611465081
# Using a p of  0.009068149441355245
# Using a p of  0.007406529685701493
# Using a p of  0.006047521873600132
# Using a p of  0.004936635218900832
# Using a p of  0.004028983358498858
# Using a p of  0.003287661385934009
# Using a p of  0.0026823732796317037
# Using a p of  0.0021882795075905265
# Using a p of  0.0017850350245561864
# Using a p of  0.0014559898567672236
# Using a p of  0.001187527207869261
# Using a p of  0.000968517024997084
# Using a p of  0.0007898659417364615
# Using a p of  0.0006441473006074265
# Using a p of  0.0005252974713971296
# Using a p of  0.00042836689448632817
# Using a p of  0.00034931619233910023
# Using a p of  0.00028484932661867926
# Using a p of  0.000232277160288464
# Using a p of  0.00018940594382518605
# Using a p of  0.0001544462123729689
# Using a p of  0.0001259383844336104
# Using a p of  0.00010269201788605237
# Using a p of  8.373622806675614e-05
# Using a p of  6.827922460227623e-05
# Using a p of  5.5675295113294124e-05
# Using a p of  4.5397868702434395e-05

# %%
plt.plot(epsilon_range, errors_all)
plt.plot(epsilon_range, errors_10)
plt.plot(epsilon_range, errors_100)
plt.plot(epsilon_range, errors_1000)
plt.plot(epsilon_range, errors_10000)
plt.legend(["1", "1/10", "1/100", "1/1000", "1/10000"])
